# %%
# %load_ext autoreload
# %autoreload 2

import sys, pathlib

# point to your "src" directory (adjust if your notebook isn't in project_root/notebooks)
project_root = pathlib.Path.cwd().parent      # if you're in notebooks/
src_path = project_root / "src"
sys.path.append(str(src_path))

# now you can import
from storm import storm          # imports the module storm/storm.py
import scanpy as sc

# %%
adata = sc.read_h5ad("/gpfs/home/asun/jin_lab/perturbench/raw_data/boli_perturb_ctx_edit_ntsubset_hvg/adata.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 33038 × 32285
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'seurat_clusters', 'Assign', 'scds', 'cxds', 'bcds', 'Sample', 'nCount_refAssay', 'nFeature_refAssay', 'predicted.subclass.score', 'predicted.subclass', 'CT', 'mito', 'BioSamp', 'CT2', 'ForPlot', 'Remove', 'active_ident', 'Assign_edit'
#     var: 'variable_gene', 'gene_name', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg', 'log1p'
#     obsm: 'X_hvg'
#     layers: 'counts'

# %%
adata.obs[adata.obs["predicted.subclass"] == "Endo"]
# Out:
#                                        orig.ident  nCount_RNA  nFeature_RNA  \
# batch1_samp1_chan3_CCACCTATCGTTGACA-1      batch1        1865          1220
# batch1_samp2_chan4_GGGAGATAGGGTTTCT-1      batch1         661           552
# batch2_mouse2_chan6_CTTGGCTAGCACCGTC-1     batch2        4272          2490
# batch2_mouse3_chan7_CAGCTGGCACACCGCA-1     batch2         907           653
# batch2_mouse3_chan7_GTCACGGTCATACGGT-1     batch2        1129           801
# batch2_mouse3_chan7_TTGACTTTCGTCCGTT-1     batch2         964           768
#
#                                        seurat_clusters    Assign      scds  \
# batch1_samp1_chan3_CCACCTATCGTTGACA-1               35    Trio_0  0.029994
# batch1_samp2_chan4_GGGAGATAGGGTTTCT-1               35  Bcl11b_0  0.009467
# batch2_mouse2_chan6_CTTGGCTAGCACCGTC-1              35  Rb1cc1_0  0.049120
# batch2_mouse3_chan7_CAGCTGGCACACCGCA-1              35  Bcl11b_0  0.009524
# batch2_mouse3_chan7_GTCACGGTCATACGGT-1              35  Bcl11b_0  0.003085
# batch2_mouse3_chan7_TTGACTTTCGTCCGTT-1              35  Rb1cc1_0  0.004920
#
#                                               cxds      bcds  \
# batch1_samp1_chan3_CCACCTATCGTTGACA-1   296.752687  0.031393
# batch1_samp2_chan4_GGGAGATAGGGTTTCT-1   690.768517  0.002660
# batch2_mouse2_chan6_CTTGGCTAGCACCGTC-1  405.748168  0.029659
# batch2_mouse3_chan7_CAGCTGGCACACCGCA-1    0.013401  0.010748
# batch2_mouse3_chan7_GTCACGGTCATACGGT-1    5.201068  0.003906
# batch2_mouse3_chan7_TTGACTTTCGTCCGTT-1    0.005186  0.006184
#
#                                                      Sample  nCount_refAssay  \
# batch1_samp1_chan3_CCACCTATCGTTGACA-1    batch1_samp1_chan3             1865
# batch1_samp2_chan4_GGGAGATAGGGTTTCT-1    batch1_samp2_chan4              661
# batch2_mouse2_chan6_CTTGGCTAGCACCGTC-1  batch2_mouse2_chan6             4272
# batch2_mouse3_chan7_CAGCTGGCACACCGCA-1  batch2_mouse3_chan7              907
# batch2_mouse3_chan7_GTCACGGTCATACGGT-1  batch2_mouse3_chan7             1129
# batch2_mouse3_chan7_TTGACTTTCGTCCGTT-1  batch2_mouse3_chan7              964
#
#                                         ...  predicted.subclass.score  \
# batch1_samp1_chan3_CCACCTATCGTTGACA-1   ...                       1.0
# batch1_samp2_chan4_GGGAGATAGGGTTTCT-1   ...                       1.0
# batch2_mouse2_chan6_CTTGGCTAGCACCGTC-1  ...                       1.0
# batch2_mouse3_chan7_CAGCTGGCACACCGCA-1  ...                       1.0
# batch2_mouse3_chan7_GTCACGGTCATACGGT-1  ...                       1.0
# batch2_mouse3_chan7_TTGACTTTCGTCCGTT-1  ...                       1.0
#
#                                         predicted.subclass         CT  \
# batch1_samp1_chan3_CCACCTATCGTTGACA-1                 Endo  Micro-PVM
# batch1_samp2_chan4_GGGAGATAGGGTTTCT-1                 Endo  Micro-PVM
# batch2_mouse2_chan6_CTTGGCTAGCACCGTC-1                Endo  Micro-PVM
# batch2_mouse3_chan7_CAGCTGGCACACCGCA-1                Endo  Micro-PVM
# batch2_mouse3_chan7_GTCACGGTCATACGGT-1                Endo  Micro-PVM
# batch2_mouse3_chan7_TTGACTTTCGTCCGTT-1                Endo  Micro-PVM
#
#                                             mito        BioSamp  \
# batch1_samp1_chan3_CCACCTATCGTTGACA-1   0.536193   batch1_samp1
# batch1_samp2_chan4_GGGAGATAGGGTTTCT-1   0.302572   batch1_samp2
# batch2_mouse2_chan6_CTTGGCTAGCACCGTC-1  0.561798  batch2_mouse2
# batch2_mouse3_chan7_CAGCTGGCACACCGCA-1  0.220507  batch2_mouse3
# batch2_mouse3_chan7_GTCACGGTCATACGGT-1  0.088574  batch2_mouse3
# batch2_mouse3_chan7_TTGACTTTCGTCCGTT-1  0.000000  batch2_mouse3
#
#                                                      CT2  \
# batch1_samp1_chan3_CCACCTATCGTTGACA-1   334 Microglia NN
# batch1_samp2_chan4_GGGAGATAGGGTTTCT-1   334 Microglia NN
# batch2_mouse2_chan6_CTTGGCTAGCACCGTC-1  334 Microglia NN
# batch2_mouse3_chan7_CAGCTGGCACACCGCA-1  334 Microglia NN
# batch2_mouse3_chan7_GTCACGGTCATACGGT-1  334 Microglia NN
# batch2_mouse3_chan7_TTGACTTTCGTCCGTT-1  334 Microglia NN
#
#                                                        ForPlot Remove  \
# batch1_samp1_chan3_CCACCTATCGTTGACA-1      batch1_samp1_Trio_0  False
# batch1_samp2_chan4_GGGAGATAGGGTTTCT-1    batch1_samp2_Bcl11b_0  False
# batch2_mouse2_chan6_CTTGGCTAGCACCGTC-1  batch2_mouse2_Rb1cc1_0  False
# batch2_mouse3_chan7_CAGCTGGCACACCGCA-1  batch2_mouse3_Bcl11b_0  False
# batch2_mouse3_chan7_GTCACGGTCATACGGT-1  batch2_mouse3_Bcl11b_0  False
# batch2_mouse3_chan7_TTGACTTTCGTCCGTT-1  batch2_mouse3_Rb1cc1_0  False
#
#                                         active_ident Assign_edit
# batch1_samp1_chan3_CCACCTATCGTTGACA-1             35        Trio
# batch1_samp2_chan4_GGGAGATAGGGTTTCT-1             35      Bcl11b
# batch2_mouse2_chan6_CTTGGCTAGCACCGTC-1            35      Rb1cc1
# batch2_mouse3_chan7_CAGCTGGCACACCGCA-1            35      Bcl11b
# batch2_mouse3_chan7_GTCACGGTCATACGGT-1            35      Bcl11b
# batch2_mouse3_chan7_TTGACTTTCGTCCGTT-1            35      Rb1cc1
#
# [6 rows x 21 columns]

# %%
type(adata.obs)
# Out:
# pandas.core.frame.DataFrame

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 32931 × 32285
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'seurat_clusters', 'Assign', 'scds', 'cxds', 'bcds', 'Sample', 'nCount_refAssay', 'nFeature_refAssay', 'predicted.subclass.score', 'predicted.subclass', 'CT', 'mito', 'BioSamp', 'CT2', 'ForPlot', 'Remove', 'active_ident', 'Assign_edit', 'transfer_split_seed1'
#     var: 'variable_gene', 'gene_name', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'hvg', 'log1p'
#     obsm: 'X_hvg'
#     layers: 'counts'

# %%
adata = storm.check_coverage_adata(adata, condition_col="Assign", control_value="NT_0", covariate_col="predicted.subclass")
# Out:
# Cell types with 0 training examples (before removal):
#   - Astro
#   - CR
#   - Endo
#   - L2 IT ENTl
#   - L2 IT RHP
#   - L6 IT ENTl
#   - L6b-CT ENT
#   - Micro-PVM
#   - SMC-Peri
#   - SUB-ProS
#   - V3d
# Number of cell types with 0 training examples: 11
# Number of cell types with 0 validation examples: 15
# Number of cell types with 0 test examples: 11
# Dropping cell types with 0 training examples from AnnData:
#   - dropping Astro
#   - dropping CR
#   - dropping Endo
#   - dropping L2 IT ENTl
#   - dropping L2 IT RHP
#   - dropping L6 IT ENTl
#   - dropping L6b-CT ENT
#   - dropping Micro-PVM
#   - dropping SMC-Peri
#   - dropping SUB-ProS
#   - dropping V3d
# Cell types with 0 validation or 0 test examples after dropping no-train types; setting all of their splits to 'train':
#   - Car3
#   - L2-3 IT PPP
#   - L5 PPP
#   - NP PPP
#   - Oligo
#   - Sncg
#   - VLMC

# %%
adata.obs[adata.obs["predicted.subclass"] == "Car3"]
# Out:
#                                        orig.ident  nCount_RNA  nFeature_RNA  \
# batch1_samp1_chan1_ATCGAGTTCCCATTTA-1      batch1        2238          1384
# batch1_samp1_chan1_ATGGGAGCATCGGAAG-1      batch1        5540          2829
# batch1_samp1_chan1_CCTCAGTTCCCGACTT-1      batch1        6585          2765
# batch1_samp1_chan1_GAAATGAGTTAGATGA-1      batch1       11108          4143
# batch1_samp1_chan1_GGTGTTACACGGCTAC-1      batch1        4312          2243
# batch1_samp1_chan1_GTCTCGTTCCACTGGG-1      batch1        9615          3659
# batch1_samp1_chan1_TCGCGAGGTACTTCTT-1      batch1        7767          3211
# batch1_samp1_chan1_TGTCCCATCATCGCTC-1      batch1        3866          2042
# batch1_samp1_chan1_TTTATGCAGACTAGGC-1      batch1        5842          2732
# batch1_samp2_chan2_CACACCTGTTCGTGAT-1      batch1        8618          3423
# batch1_samp1_chan3_CGGAGCTCAGTTAACC-1      batch1        5131          2717
# batch1_samp1_chan3_CTGTGCTAGAATCTCC-1      batch1        6418          2626
# batch1_samp1_chan3_GGGTCTGAGAAACCGC-1      batch1        6203          2990
# batch1_samp1_chan3_GTAACGTAGCTAGTTC-1      batch1        8352          3272
# batch1_samp1_chan3_GTAGGCCCATGCAATC-1      batch1        4129          2377
# batch1_samp1_chan3_GTCAAGTCACCGAATT-1      batch1       11537          4158
# batch1_samp1_chan3_TAGAGCTAGATGTAAC-1      batch1        5678          2798
# batch1_samp1_chan3_TGTGGTACAATCCGAT-1      batch1        5873          2538
# batch2_mouse1_chan5_ATAACGCCAGTAAGCG-1     batch2        1600          1047
# batch2_mouse1_chan5_GAAACTCGTTAGAACA-1     batch2        9882          3805
# batch2_mouse2_chan6_AGTGGGAAGTCCCACG-1     batch2        4415          2397
# batch2_mouse2_chan6_CTACACCGTTTCGCTC-1     batch2       10187          3522
# batch2_mouse2_chan6_GAACATCCACAACGTT-1     batch2       11430          4028
# batch2_mouse2_chan6_GAGCAGATCGGCTACG-1     batch2        4487          2311
# batch2_mouse2_chan6_TAGTGGTAGCTTTGGT-1     batch2       11012          3926
# batch2_mouse3_chan7_AAAGATGGTCTAGTGT-1     batch2        6647          3006
# batch2_mouse3_chan7_AAAGATGGTGGGTATG-1     batch2       11338          4534
# batch2_mouse3_chan7_CCTACACGTAGAGCTG-1     batch2        7265          3235
# batch2_mouse3_chan7_GTACTCCTCACGATGT-1     batch2        8901          3581
# batch2_mouse3_chan7_TCGCGAGGTAAATGTG-1     batch2        7236          3012
#
#                                        seurat_clusters    Assign      scds  \
# batch1_samp1_chan1_ATCGAGTTCCCATTTA-1               37  Bcl11b_0  0.087685
# batch1_samp1_chan1_ATGGGAGCATCGGAAG-1               37    Trio_0  1.125431
# batch1_samp1_chan1_CCTCAGTTCCCGACTT-1                2  Bcl11b_0  0.734729
# batch1_samp1_chan1_GAAATGAGTTAGATGA-1               37      NT_0  1.635007
# batch1_samp1_chan1_GGTGTTACACGGCTAC-1               37   Satb2_0  0.455656
# batch1_samp1_chan1_GTCTCGTTCCACTGGG-1                2    Trio_0  1.414420
# batch1_samp1_chan1_TCGCGAGGTACTTCTT-1               37    Trio_0  1.429955
# batch1_samp1_chan1_TGTCCCATCATCGCTC-1               37      NT_0  0.103254
# batch1_samp1_chan1_TTTATGCAGACTAGGC-1               37    Dab1_0  0.900965
# batch1_samp2_chan2_CACACCTGTTCGTGAT-1               37  Bcl11b_0  0.407658
# batch1_samp1_chan3_CGGAGCTCAGTTAACC-1               37    Dab1_0  0.180575
# batch1_samp1_chan3_CTGTGCTAGAATCTCC-1               37  Rb1cc1_0  0.803426
# batch1_samp1_chan3_GGGTCTGAGAAACCGC-1               37    Trio_0  0.221264
# batch1_samp1_chan3_GTAACGTAGCTAGTTC-1               37      NT_0  0.419064
# batch1_samp1_chan3_GTAGGCCCATGCAATC-1               37  Bcl11b_0  0.164288
# batch1_samp1_chan3_GTCAAGTCACCGAATT-1                2    Xpo7_0  1.525431
# batch1_samp1_chan3_TAGAGCTAGATGTAAC-1               37      NT_0  0.261261
# batch1_samp1_chan3_TGTGGTACAATCCGAT-1               37      NT_0  0.231668
# batch2_mouse1_chan5_ATAACGCCAGTAAGCG-1              37    Dab1_0  0.032702
# batch2_mouse1_chan5_GAAACTCGTTAGAACA-1              37    Xpo7_0  0.417412
# batch2_mouse2_chan6_AGTGGGAAGTCCCACG-1              37  Bcl11b_0  0.199543
# batch2_mouse2_chan6_CTACACCGTTTCGCTC-1              37    Trio_0  0.361696
# batch2_mouse2_chan6_GAACATCCACAACGTT-1              37    Cul1_0  0.356148
# batch2_mouse2_chan6_GAGCAGATCGGCTACG-1              37   Satb2_0  0.416294
# batch2_mouse2_chan6_TAGTGGTAGCTTTGGT-1              37   Satb2_0  0.685755
# batch2_mouse3_chan7_AAAGATGGTCTAGTGT-1              37   Herc1_0  0.544527
# batch2_mouse3_chan7_AAAGATGGTGGGTATG-1              37    Xpo7_0  1.426129
# batch2_mouse3_chan7_CCTACACGTAGAGCTG-1              37      NT_0  0.690604
# batch2_mouse3_chan7_GTACTCCTCACGATGT-1              37    Xpo7_0  0.622153
# batch2_mouse3_chan7_TCGCGAGGTAAATGTG-1              37    Dab1_0  0.347734
#
#                                                 cxds      bcds  \
# batch1_samp1_chan1_ATCGAGTTCCCATTTA-1    5550.202788  0.005188
# batch1_samp1_chan1_ATGGGAGCATCGGAAG-1   15879.357431  0.878353
# batch1_samp1_chan1_CCTCAGTTCCCGACTT-1   12726.859214  0.538730
# batch1_samp1_chan1_GAAATGAGTTAGATGA-1   56179.850247  0.786368
# batch1_samp1_chan1_GGTGTTACACGGCTAC-1   15716.921235  0.218656
# batch1_samp1_chan1_GTCTCGTTCCACTGGG-1   30265.625907  0.951372
# batch1_samp1_chan1_TCGCGAGGTACTTCTT-1   33610.932593  0.917279
# batch1_samp1_chan1_TGTCCCATCATCGCTC-1    6374.678213  0.008391
# batch1_samp1_chan1_TTTATGCAGACTAGGC-1   29818.086850  0.450419
# batch1_samp2_chan2_CACACCTGTTCGTGAT-1   17448.208809  0.009882
# batch1_samp1_chan3_CGGAGCTCAGTTAACC-1   10925.242810  0.047569
# batch1_samp1_chan3_CTGTGCTAGAATCTCC-1   22954.332544  0.502679
# batch1_samp1_chan3_GGGTCTGAGAAACCGC-1   10881.702542  0.087383
# batch1_samp1_chan3_GTAACGTAGCTAGTTC-1   28814.972530  0.060348
# batch1_samp1_chan3_GTAGGCCCATGCAATC-1    9970.715146  0.043449
# batch1_samp1_chan3_GTCAAGTCACCGAATT-1   45675.547538  0.923541
# batch1_samp1_chan3_TAGAGCTAGATGTAAC-1   12878.137149  0.101729
# batch1_samp1_chan3_TGTGGTACAATCCGAT-1   15574.649651  0.040379
# batch2_mouse1_chan5_ATAACGCCAGTAAGCG-1    685.807219  0.009527
# batch2_mouse1_chan5_GAAACTCGTTAGAACA-1   9642.948063  0.069434
# batch2_mouse2_chan6_AGTGGGAAGTCCCACG-1   3568.482948  0.024119
# batch2_mouse2_chan6_CTACACCGTTTCGCTC-1   6064.838352  0.062833
# batch2_mouse2_chan6_GAACATCCACAACGTT-1   5513.033242  0.084337
# batch2_mouse2_chan6_GAGCAGATCGGCTACG-1   7455.535546  0.048941
# batch2_mouse2_chan6_TAGTGGTAGCTTTGGT-1   8705.028892  0.255169
# batch2_mouse3_chan7_AAAGATGGTCTAGTGT-1   3293.905400  0.249927
# batch2_mouse3_chan7_AAAGATGGTGGGTATG-1   4934.913918  0.978817
# batch2_mouse3_chan7_CCTACACGTAGAGCTG-1   2258.994762  0.486225
# batch2_mouse3_chan7_GTACTCCTCACGATGT-1   2406.848323  0.405297
# batch2_mouse3_chan7_TCGCGAGGTAAATGTG-1   2557.979842  0.119898
#
#                                                      Sample  nCount_refAssay  \
# batch1_samp1_chan1_ATCGAGTTCCCATTTA-1    batch1_samp1_chan1             2238
# batch1_samp1_chan1_ATGGGAGCATCGGAAG-1    batch1_samp1_chan1             5540
# batch1_samp1_chan1_CCTCAGTTCCCGACTT-1    batch1_samp1_chan1             6585
# batch1_samp1_chan1_GAAATGAGTTAGATGA-1    batch1_samp1_chan1            11108
# batch1_samp1_chan1_GGTGTTACACGGCTAC-1    batch1_samp1_chan1             4312
# batch1_samp1_chan1_GTCTCGTTCCACTGGG-1    batch1_samp1_chan1             9615
# batch1_samp1_chan1_TCGCGAGGTACTTCTT-1    batch1_samp1_chan1             7767
# batch1_samp1_chan1_TGTCCCATCATCGCTC-1    batch1_samp1_chan1             3866
# batch1_samp1_chan1_TTTATGCAGACTAGGC-1    batch1_samp1_chan1             5842
# batch1_samp2_chan2_CACACCTGTTCGTGAT-1    batch1_samp2_chan2             8618
# batch1_samp1_chan3_CGGAGCTCAGTTAACC-1    batch1_samp1_chan3             5131
# batch1_samp1_chan3_CTGTGCTAGAATCTCC-1    batch1_samp1_chan3             6418
# batch1_samp1_chan3_GGGTCTGAGAAACCGC-1    batch1_samp1_chan3             6203
# batch1_samp1_chan3_GTAACGTAGCTAGTTC-1    batch1_samp1_chan3             8352
# batch1_samp1_chan3_GTAGGCCCATGCAATC-1    batch1_samp1_chan3             4129
# batch1_samp1_chan3_GTCAAGTCACCGAATT-1    batch1_samp1_chan3            11537
# batch1_samp1_chan3_TAGAGCTAGATGTAAC-1    batch1_samp1_chan3             5678
# batch1_samp1_chan3_TGTGGTACAATCCGAT-1    batch1_samp1_chan3             5873
# batch2_mouse1_chan5_ATAACGCCAGTAAGCG-1  batch2_mouse1_chan5             1600
# batch2_mouse1_chan5_GAAACTCGTTAGAACA-1  batch2_mouse1_chan5             9882
# batch2_mouse2_chan6_AGTGGGAAGTCCCACG-1  batch2_mouse2_chan6             4415
# batch2_mouse2_chan6_CTACACCGTTTCGCTC-1  batch2_mouse2_chan6            10187
# batch2_mouse2_chan6_GAACATCCACAACGTT-1  batch2_mouse2_chan6            11430
# batch2_mouse2_chan6_GAGCAGATCGGCTACG-1  batch2_mouse2_chan6             4487
# batch2_mouse2_chan6_TAGTGGTAGCTTTGGT-1  batch2_mouse2_chan6            11012
# batch2_mouse3_chan7_AAAGATGGTCTAGTGT-1  batch2_mouse3_chan7             6647
# batch2_mouse3_chan7_AAAGATGGTGGGTATG-1  batch2_mouse3_chan7            11338
# batch2_mouse3_chan7_CCTACACGTAGAGCTG-1  batch2_mouse3_chan7             7265
# batch2_mouse3_chan7_GTACTCCTCACGATGT-1  batch2_mouse3_chan7             8901
# batch2_mouse3_chan7_TCGCGAGGTAAATGTG-1  batch2_mouse3_chan7             7236
#
#                                         ...  predicted.subclass         CT  \
# batch1_samp1_chan1_ATCGAGTTCCCATTTA-1   ...                Car3       Car3
# batch1_samp1_chan1_ATGGGAGCATCGGAAG-1   ...                Car3       Car3
# batch1_samp1_chan1_CCTCAGTTCCCGACTT-1   ...                Car3  L6 IT CTX
# batch1_samp1_chan1_GAAATGAGTTAGATGA-1   ...                Car3       Car3
# batch1_samp1_chan1_GGTGTTACACGGCTAC-1   ...                Car3       Car3
# batch1_samp1_chan1_GTCTCGTTCCACTGGG-1   ...                Car3  L6 IT CTX
# batch1_samp1_chan1_TCGCGAGGTACTTCTT-1   ...                Car3       Car3
# batch1_samp1_chan1_TGTCCCATCATCGCTC-1   ...                Car3       Car3
# batch1_samp1_chan1_TTTATGCAGACTAGGC-1   ...                Car3       Car3
# batch1_samp2_chan2_CACACCTGTTCGTGAT-1   ...                Car3       Car3
# batch1_samp1_chan3_CGGAGCTCAGTTAACC-1   ...                Car3       Car3
# batch1_samp1_chan3_CTGTGCTAGAATCTCC-1   ...                Car3       Car3
# batch1_samp1_chan3_GGGTCTGAGAAACCGC-1   ...                Car3       Car3
# batch1_samp1_chan3_GTAACGTAGCTAGTTC-1   ...                Car3       Car3
# batch1_samp1_chan3_GTAGGCCCATGCAATC-1   ...                Car3       Car3
# batch1_samp1_chan3_GTCAAGTCACCGAATT-1   ...                Car3  L6 IT CTX
# batch1_samp1_chan3_TAGAGCTAGATGTAAC-1   ...                Car3       Car3
# batch1_samp1_chan3_TGTGGTACAATCCGAT-1   ...                Car3       Car3
# batch2_mouse1_chan5_ATAACGCCAGTAAGCG-1  ...                Car3       Car3
# batch2_mouse1_chan5_GAAACTCGTTAGAACA-1  ...                Car3       Car3
# batch2_mouse2_chan6_AGTGGGAAGTCCCACG-1  ...                Car3       Car3
# batch2_mouse2_chan6_CTACACCGTTTCGCTC-1  ...                Car3       Car3
# batch2_mouse2_chan6_GAACATCCACAACGTT-1  ...                Car3       Car3
# batch2_mouse2_chan6_GAGCAGATCGGCTACG-1  ...                Car3       Car3
# batch2_mouse2_chan6_TAGTGGTAGCTTTGGT-1  ...                Car3       Car3
# batch2_mouse3_chan7_AAAGATGGTCTAGTGT-1  ...                Car3       Car3
# batch2_mouse3_chan7_AAAGATGGTGGGTATG-1  ...                Car3       Car3
# batch2_mouse3_chan7_CCTACACGTAGAGCTG-1  ...                Car3       Car3
# batch2_mouse3_chan7_GTACTCCTCACGATGT-1  ...                Car3       Car3
# batch2_mouse3_chan7_TCGCGAGGTAAATGTG-1  ...                Car3       Car3
#
#                                             mito        BioSamp  \
# batch1_samp1_chan1_ATCGAGTTCCCATTTA-1   0.000000   batch1_samp1
# batch1_samp1_chan1_ATGGGAGCATCGGAAG-1   0.000000   batch1_samp1
# batch1_samp1_chan1_CCTCAGTTCCCGACTT-1   0.030372   batch1_samp1
# batch1_samp1_chan1_GAAATGAGTTAGATGA-1   0.018005   batch1_samp1
# batch1_samp1_chan1_GGTGTTACACGGCTAC-1   0.185529   batch1_samp1
# batch1_samp1_chan1_GTCTCGTTCCACTGGG-1   0.000000   batch1_samp1
# batch1_samp1_chan1_TCGCGAGGTACTTCTT-1   0.000000   batch1_samp1
# batch1_samp1_chan1_TGTCCCATCATCGCTC-1   0.051733   batch1_samp1
# batch1_samp1_chan1_TTTATGCAGACTAGGC-1   0.496405   batch1_samp1
# batch1_samp2_chan2_CACACCTGTTCGTGAT-1   0.011604   batch1_samp2
# batch1_samp1_chan3_CGGAGCTCAGTTAACC-1   0.000000   batch1_samp1
# batch1_samp1_chan3_CTGTGCTAGAATCTCC-1   0.000000   batch1_samp1
# batch1_samp1_chan3_GGGTCTGAGAAACCGC-1   0.000000   batch1_samp1
# batch1_samp1_chan3_GTAACGTAGCTAGTTC-1   0.011973   batch1_samp1
# batch1_samp1_chan3_GTAGGCCCATGCAATC-1   0.048438   batch1_samp1
# batch1_samp1_chan3_GTCAAGTCACCGAATT-1   0.112681   batch1_samp1
# batch1_samp1_chan3_TAGAGCTAGATGTAAC-1   0.000000   batch1_samp1
# batch1_samp1_chan3_TGTGGTACAATCCGAT-1   0.000000   batch1_samp1
# batch2_mouse1_chan5_ATAACGCCAGTAAGCG-1  0.125000  batch2_mouse1
# batch2_mouse1_chan5_GAAACTCGTTAGAACA-1  0.030358  batch2_mouse1
# batch2_mouse2_chan6_AGTGGGAAGTCCCACG-1  0.135900  batch2_mouse2
# batch2_mouse2_chan6_CTACACCGTTTCGCTC-1  0.009816  batch2_mouse2
# batch2_mouse2_chan6_GAACATCCACAACGTT-1  0.017498  batch2_mouse2
# batch2_mouse2_chan6_GAGCAGATCGGCTACG-1  0.022287  batch2_mouse2
# batch2_mouse2_chan6_TAGTGGTAGCTTTGGT-1  0.072648  batch2_mouse2
# batch2_mouse3_chan7_AAAGATGGTCTAGTGT-1  0.060178  batch2_mouse3
# batch2_mouse3_chan7_AAAGATGGTGGGTATG-1  0.035280  batch2_mouse3
# batch2_mouse3_chan7_CCTACACGTAGAGCTG-1  0.013765  batch2_mouse3
# batch2_mouse3_chan7_GTACTCCTCACGATGT-1  0.011235  batch2_mouse3
# batch2_mouse3_chan7_TCGCGAGGTAAATGTG-1  0.013820  batch2_mouse3
#
#                                                               CT2  \
# batch1_samp1_chan1_ATCGAGTTCCCATTTA-1   001 CLA-EPd-CTX Car3 Glut
# batch1_samp1_chan1_ATGGGAGCATCGGAAG-1   001 CLA-EPd-CTX Car3 Glut
# batch1_samp1_chan1_CCTCAGTTCCCGACTT-1          004 L6 IT CTX Glut
# batch1_samp1_chan1_GAAATGAGTTAGATGA-1   001 CLA-EPd-CTX Car3 Glut
# batch1_samp1_chan1_GGTGTTACACGGCTAC-1   001 CLA-EPd-CTX Car3 Glut
# batch1_samp1_chan1_GTCTCGTTCCACTGGG-1          004 L6 IT CTX Glut
# batch1_samp1_chan1_TCGCGAGGTACTTCTT-1   001 CLA-EPd-CTX Car3 Glut
# batch1_samp1_chan1_TGTCCCATCATCGCTC-1   001 CLA-EPd-CTX Car3 Glut
# batch1_samp1_chan1_TTTATGCAGACTAGGC-1   001 CLA-EPd-CTX Car3 Glut
# batch1_samp2_chan2_CACACCTGTTCGTGAT-1   001 CLA-EPd-CTX Car3 Glut
# batch1_samp1_chan3_CGGAGCTCAGTTAACC-1   001 CLA-EPd-CTX Car3 Glut
# batch1_samp1_chan3_CTGTGCTAGAATCTCC-1   001 CLA-EPd-CTX Car3 Glut
# batch1_samp1_chan3_GGGTCTGAGAAACCGC-1   001 CLA-EPd-CTX Car3 Glut
# batch1_samp1_chan3_GTAACGTAGCTAGTTC-1   001 CLA-EPd-CTX Car3 Glut
# batch1_samp1_chan3_GTAGGCCCATGCAATC-1   001 CLA-EPd-CTX Car3 Glut
# batch1_samp1_chan3_GTCAAGTCACCGAATT-1          004 L6 IT CTX Glut
# batch1_samp1_chan3_TAGAGCTAGATGTAAC-1   001 CLA-EPd-CTX Car3 Glut
# batch1_samp1_chan3_TGTGGTACAATCCGAT-1   001 CLA-EPd-CTX Car3 Glut
# batch2_mouse1_chan5_ATAACGCCAGTAAGCG-1  001 CLA-EPd-CTX Car3 Glut
# batch2_mouse1_chan5_GAAACTCGTTAGAACA-1  001 CLA-EPd-CTX Car3 Glut
# batch2_mouse2_chan6_AGTGGGAAGTCCCACG-1  001 CLA-EPd-CTX Car3 Glut
# batch2_mouse2_chan6_CTACACCGTTTCGCTC-1  001 CLA-EPd-CTX Car3 Glut
# batch2_mouse2_chan6_GAACATCCACAACGTT-1  001 CLA-EPd-CTX Car3 Glut
# batch2_mouse2_chan6_GAGCAGATCGGCTACG-1  001 CLA-EPd-CTX Car3 Glut
# batch2_mouse2_chan6_TAGTGGTAGCTTTGGT-1  001 CLA-EPd-CTX Car3 Glut
# batch2_mouse3_chan7_AAAGATGGTCTAGTGT-1  001 CLA-EPd-CTX Car3 Glut
# batch2_mouse3_chan7_AAAGATGGTGGGTATG-1  001 CLA-EPd-CTX Car3 Glut
# batch2_mouse3_chan7_CCTACACGTAGAGCTG-1  001 CLA-EPd-CTX Car3 Glut
# batch2_mouse3_chan7_GTACTCCTCACGATGT-1  001 CLA-EPd-CTX Car3 Glut
# batch2_mouse3_chan7_TCGCGAGGTAAATGTG-1  001 CLA-EPd-CTX Car3 Glut
#
#                                                        ForPlot Remove  \
# batch1_samp1_chan1_ATCGAGTTCCCATTTA-1    batch1_samp1_Bcl11b_0  False
# batch1_samp1_chan1_ATGGGAGCATCGGAAG-1      batch1_samp1_Trio_0  False
# batch1_samp1_chan1_CCTCAGTTCCCGACTT-1    batch1_samp1_Bcl11b_0  False
# batch1_samp1_chan1_GAAATGAGTTAGATGA-1        batch1_samp1_NT_0  False
# batch1_samp1_chan1_GGTGTTACACGGCTAC-1     batch1_samp1_Satb2_0  False
# batch1_samp1_chan1_GTCTCGTTCCACTGGG-1      batch1_samp1_Trio_0  False
# batch1_samp1_chan1_TCGCGAGGTACTTCTT-1      batch1_samp1_Trio_0  False
# batch1_samp1_chan1_TGTCCCATCATCGCTC-1        batch1_samp1_NT_0  False
# batch1_samp1_chan1_TTTATGCAGACTAGGC-1      batch1_samp1_Dab1_0  False
# batch1_samp2_chan2_CACACCTGTTCGTGAT-1    batch1_samp2_Bcl11b_0  False
# batch1_samp1_chan3_CGGAGCTCAGTTAACC-1      batch1_samp1_Dab1_0  False
# batch1_samp1_chan3_CTGTGCTAGAATCTCC-1    batch1_samp1_Rb1cc1_0  False
# batch1_samp1_chan3_GGGTCTGAGAAACCGC-1      batch1_samp1_Trio_0  False
# batch1_samp1_chan3_GTAACGTAGCTAGTTC-1        batch1_samp1_NT_0  False
# batch1_samp1_chan3_GTAGGCCCATGCAATC-1    batch1_samp1_Bcl11b_0  False
# batch1_samp1_chan3_GTCAAGTCACCGAATT-1      batch1_samp1_Xpo7_0  False
# batch1_samp1_chan3_TAGAGCTAGATGTAAC-1        batch1_samp1_NT_0  False
# batch1_samp1_chan3_TGTGGTACAATCCGAT-1        batch1_samp1_NT_0  False
# batch2_mouse1_chan5_ATAACGCCAGTAAGCG-1    batch2_mouse1_Dab1_0  False
# batch2_mouse1_chan5_GAAACTCGTTAGAACA-1    batch2_mouse1_Xpo7_0  False
# batch2_mouse2_chan6_AGTGGGAAGTCCCACG-1  batch2_mouse2_Bcl11b_0  False
# batch2_mouse2_chan6_CTACACCGTTTCGCTC-1    batch2_mouse2_Trio_0  False
# batch2_mouse2_chan6_GAACATCCACAACGTT-1    batch2_mouse2_Cul1_0  False
# batch2_mouse2_chan6_GAGCAGATCGGCTACG-1   batch2_mouse2_Satb2_0  False
# batch2_mouse2_chan6_TAGTGGTAGCTTTGGT-1   batch2_mouse2_Satb2_0  False
# batch2_mouse3_chan7_AAAGATGGTCTAGTGT-1   batch2_mouse3_Herc1_0  False
# batch2_mouse3_chan7_AAAGATGGTGGGTATG-1    batch2_mouse3_Xpo7_0  False
# batch2_mouse3_chan7_CCTACACGTAGAGCTG-1      batch2_mouse3_NT_0  False
# batch2_mouse3_chan7_GTACTCCTCACGATGT-1    batch2_mouse3_Xpo7_0  False
# batch2_mouse3_chan7_TCGCGAGGTAAATGTG-1    batch2_mouse3_Dab1_0  False
#
#                                        active_ident  Assign_edit  \
# batch1_samp1_chan1_ATCGAGTTCCCATTTA-1            37       Bcl11b
# batch1_samp1_chan1_ATGGGAGCATCGGAAG-1            37         Trio
# batch1_samp1_chan1_CCTCAGTTCCCGACTT-1             2       Bcl11b
# batch1_samp1_chan1_GAAATGAGTTAGATGA-1            37         Ctrl
# batch1_samp1_chan1_GGTGTTACACGGCTAC-1            37        Satb2
# batch1_samp1_chan1_GTCTCGTTCCACTGGG-1             2         Trio
# batch1_samp1_chan1_TCGCGAGGTACTTCTT-1            37         Trio
# batch1_samp1_chan1_TGTCCCATCATCGCTC-1            37         Ctrl
# batch1_samp1_chan1_TTTATGCAGACTAGGC-1            37         Dab1
# batch1_samp2_chan2_CACACCTGTTCGTGAT-1            37       Bcl11b
# batch1_samp1_chan3_CGGAGCTCAGTTAACC-1            37         Dab1
# batch1_samp1_chan3_CTGTGCTAGAATCTCC-1            37       Rb1cc1
# batch1_samp1_chan3_GGGTCTGAGAAACCGC-1            37         Trio
# batch1_samp1_chan3_GTAACGTAGCTAGTTC-1            37         Ctrl
# batch1_samp1_chan3_GTAGGCCCATGCAATC-1            37       Bcl11b
# batch1_samp1_chan3_GTCAAGTCACCGAATT-1             2         Xpo7
# batch1_samp1_chan3_TAGAGCTAGATGTAAC-1            37         Ctrl
# batch1_samp1_chan3_TGTGGTACAATCCGAT-1            37         Ctrl
# batch2_mouse1_chan5_ATAACGCCAGTAAGCG-1           37         Dab1
# batch2_mouse1_chan5_GAAACTCGTTAGAACA-1           37         Xpo7
# batch2_mouse2_chan6_AGTGGGAAGTCCCACG-1           37       Bcl11b
# batch2_mouse2_chan6_CTACACCGTTTCGCTC-1           37         Trio
# batch2_mouse2_chan6_GAACATCCACAACGTT-1           37         Cul1
# batch2_mouse2_chan6_GAGCAGATCGGCTACG-1           37        Satb2
# batch2_mouse2_chan6_TAGTGGTAGCTTTGGT-1           37        Satb2
# batch2_mouse3_chan7_AAAGATGGTCTAGTGT-1           37        Herc1
# batch2_mouse3_chan7_AAAGATGGTGGGTATG-1           37         Xpo7
# batch2_mouse3_chan7_CCTACACGTAGAGCTG-1           37         Ctrl
# batch2_mouse3_chan7_GTACTCCTCACGATGT-1           37         Xpo7
# batch2_mouse3_chan7_TCGCGAGGTAAATGTG-1           37         Dab1
#
#                                        transfer_split_seed1
# batch1_samp1_chan1_ATCGAGTTCCCATTTA-1                 train
# batch1_samp1_chan1_ATGGGAGCATCGGAAG-1                 train
# batch1_samp1_chan1_CCTCAGTTCCCGACTT-1                 train
# batch1_samp1_chan1_GAAATGAGTTAGATGA-1                 train
# batch1_samp1_chan1_GGTGTTACACGGCTAC-1                 train
# batch1_samp1_chan1_GTCTCGTTCCACTGGG-1                 train
# batch1_samp1_chan1_TCGCGAGGTACTTCTT-1                 train
# batch1_samp1_chan1_TGTCCCATCATCGCTC-1                 train
# batch1_samp1_chan1_TTTATGCAGACTAGGC-1                 train
# batch1_samp2_chan2_CACACCTGTTCGTGAT-1                 train
# batch1_samp1_chan3_CGGAGCTCAGTTAACC-1                 train
# batch1_samp1_chan3_CTGTGCTAGAATCTCC-1                 train
# batch1_samp1_chan3_GGGTCTGAGAAACCGC-1                 train
# batch1_samp1_chan3_GTAACGTAGCTAGTTC-1                 train
# batch1_samp1_chan3_GTAGGCCCATGCAATC-1                 train
# batch1_samp1_chan3_GTCAAGTCACCGAATT-1                 train
# batch1_samp1_chan3_TAGAGCTAGATGTAAC-1                 train
# batch1_samp1_chan3_TGTGGTACAATCCGAT-1                 train
# batch2_mouse1_chan5_ATAACGCCAGTAAGCG-1                train
# batch2_mouse1_chan5_GAAACTCGTTAGAACA-1                train
# batch2_mouse2_chan6_AGTGGGAAGTCCCACG-1                train
# batch2_mouse2_chan6_CTACACCGTTTCGCTC-1                train
# batch2_mouse2_chan6_GAACATCCACAACGTT-1                train
# batch2_mouse2_chan6_GAGCAGATCGGCTACG-1                train
# batch2_mouse2_chan6_TAGTGGTAGCTTTGGT-1                train
# batch2_mouse3_chan7_AAAGATGGTCTAGTGT-1                train
# batch2_mouse3_chan7_AAAGATGGTGGGTATG-1                train
# batch2_mouse3_chan7_CCTACACGTAGAGCTG-1                train
# batch2_mouse3_chan7_GTACTCCTCACGATGT-1                train
# batch2_mouse3_chan7_TCGCGAGGTAAATGTG-1                train
#
# [30 rows x 22 columns]
